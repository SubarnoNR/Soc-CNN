# %% [markdown]
# # Assignment 4 : Neural Networks

# %% [markdown]
# In this assignment, you will design an artificial neural network for a binary classification task. We will use Keras for implementing the neural network in this assignment. You can also use numpy, pandas and/or scikit-learn wherever you find them useful. You'll also need matplotlib

# %%
# !pip install tensorflow
# Out:
# ^C

# %% [markdown]
# #### Import the required libraries here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import *

# %% [markdown]
# Load the dataset from the file named 'data.csv' . You'll find 7200 datapoints in this file. The first 6 columns are the features (X), while the last column has a binary label (Y) for each feature vector. After loading the dataset, divide it into a training set and a test set (cross-validation set to be more accurate). You can have 70% datapoints in the training set and 30% in the test set. An 80-20 split is also acceptable.
#
# Normalize your training set using mean and variances.

# %%
data = pd.read_csv("data.csv",header = None)
features = data[[*range(0,6)]]
labels = data[6]
X = np.array(features)
Y = np.array(labels)
X = preprocessing.normalize(X,axis=0)
train_set = X[0:int(len(X)*0.7)]
test_set = X[int(len(X)*0.7):]
train_labels = Y[0:int(len(X)*0.7)]
test_labels = Y[int(len(X)*0.7):]
print("{} {} {} {}".format(training_set.shape,test_set.shape,train_labels.shape,test_labels.shape))
# Out:
# (5040, 6) (2160, 6) (5040,) (2160,)

# %% [markdown]
# Find the number of positive and negative samples in the training set /test set /the whole dataset. You'll use this result while evaluating your neural network model later.

# %%
train_zero = np.count_nonzero(train_labels==0)
train_one = np.count_nonzero(train_labels)
test_zero = np.count_nonzero(test_labels==0)
test_one = np.count_nonzero(test_labels)
print("Training set - Zeros => {}".format(train_zero))
print("Training set - Ones => {}".format(train_one))
print("Test set - Zeros => {}".format(test_zero))
print("Test set - Ones => {}".format(test_one))
# Out:
# Training set - Zeros => 4670
# Training set - Ones => 370
# Test set - Zeros => 1996
# Test set - Ones => 164

# %% [markdown]
# #### Define the architecture of the neural network
#
# Initialise a sequential neural network model using keras.models.Sequential(), and add dense layers (dense layer means fully-connected layer) to it using keras.layers.Dense() (you easily how to do this from the internet).
#
# Use ReLU activation function in every layer, except the last one, where you'll use the sigmoid activation function, since it's a binary classification task.
#
# The choice of the number of layers and the number of units in a layer is totally up to you.

# %%
model = Sequential()
model.add(Dense(12, input_dim=6, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# #### Training the neural network
#
# 1. Compile your nn model using model.compile() . Use the appropriate loss function (binary cross-entropy), and use Adam optimizer. Pass on 'accuracy' as a metric, so that you get to see the accuracy on your training set after every iteration of Adam optimization (a form of mini-batch gradient descent).
#
# Try to look-up and learn a bit about what stochastic gradient descent and mini-batch gradient descent essentilly are. You'll use mini-batches while training your model.
#
# 2. Train your model using model.fit() (this will take a while, perhaps a few minutes). Use appropriate number of ephocs and batch size (you have to decide which values work the best). Don't forget that you have to train your model on the training set, and not the test set

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(train_set, train_labels, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 504/504 [==============================] - 1s 453us/step - loss: 0.4808 - accuracy: 0.9209
# Epoch 2/150
# 504/504 [==============================] - 0s 425us/step - loss: 0.2517 - accuracy: 0.9266
# Epoch 3/150
# 504/504 [==============================] - 0s 433us/step - loss: 0.2301 - accuracy: 0.9332
# Epoch 4/150
# 504/504 [==============================] - 0s 438us/step - loss: 0.2354 - accuracy: 0.9270
# Epoch 5/150
# 504/504 [==============================] - 0s 436us/step - loss: 0.2360 - accuracy: 0.9232
# Epoch 6/150
# 504/504 [==============================] - 0s 433us/step - loss: 0.2056 - accuracy: 0.9350
# Epoch 7/150
# 504/504 [==============================] - 0s 440us/step - loss: 0.1935 - accuracy: 0.9362
# Epoch 8/150
# 504/504 [==============================] - 0s 426us/step - loss: 0.1806 - accuracy: 0.9396
# Epoch 9/150
# 504/504 [==============================] - 0s 438us/step - loss: 0.1737 - accuracy: 0.9421
# Epoch 10/150
# ...

# %% [markdown]
# #### Evaluation of the model on the test set
#
# Find the accuracy of your trained model on the test set. Don't forget that you had normalized your training set before training the same model.

# %%
_,accuracy = model.evaluate(test_set, test_labels)
print("Accuracy: {}%".format(round(accuracy*100,2)))
# Out:
# 68/68 [==============================] - 0s 419us/step - loss: 0.0770 - accuracy: 0.9676
# Accuracy: 96.76%

# %%
test_prediction = (model.predict(test_set) > 0.5).astype("int32")
yhat_classes.shape
acc = accuracy_score(test_labels, test_prediction)
# Out:
# 0.9675925925925926

# %% [markdown]
# Is accuracy really the best metric to evaluate our model on the test set here? What was the proportion of positive samples to negative samples in the dataset? What would have been the accuracy of a model that would have output '0' for any input? By the way, this dataset is for detecting the presence of thyroid in a patient.
#
# Now, find out about the metrics - recall, precision and F1-score. Use these metrics to evaluate your model on the test set

# %%
precision = precision_score(test_labels, test_prediction)
recall = recall_score(test_labels, test_prediction)
f1 = f1_score(test_labels, test_prediction)
print(precision)
print(recall)
print(f1)
# Out:
# 0.7008547008547008
# 1.0
# 0.8241206030150754

# %%
#training model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.metrics.Precision()])
model.fit(train_set, train_labels, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 504/504 [==============================] - 1s 463us/step - loss: 0.0554 - precision_3: 0.7670
# Epoch 2/150
# 504/504 [==============================] - 0s 475us/step - loss: 0.0546 - precision_3: 0.7720
# Epoch 3/150
# 504/504 [==============================] - 0s 462us/step - loss: 0.0583 - precision_3: 0.7427
# Epoch 4/150
# 504/504 [==============================] - 0s 458us/step - loss: 0.0496 - precision_3: 0.7540
# Epoch 5/150
# 504/504 [==============================] - 0s 464us/step - loss: 0.0556 - precision_3: 0.7700
# Epoch 6/150
# 504/504 [==============================] - 0s 469us/step - loss: 0.0579 - precision_3: 0.7576
# Epoch 7/150
# 504/504 [==============================] - 0s 456us/step - loss: 0.0568 - precision_3: 0.7525
# Epoch 8/150
# 504/504 [==============================] - 0s 452us/step - loss: 0.0536 - precision_3: 0.7968
# Epoch 9/150
# 504/504 [==============================] - 0s 454us/step - loss: 0.0596 - precision_3: 0.7407
# ...

# %% [markdown]
# Now, tune the hyperparameters of your model (like number of layers, number of units in different layers, etc.) to try and do better and better on the test set.

# %%
#function that takes in various parameters and returns the F1 value
def F1(l1,l2):
    print("Dimension of Layer 2: {}".format(l1))
    print("Dimension of Layer 3: {}".format(l2))
    model = Sequential()
    model.add(Dense(l1, input_dim=6, activation='relu'))
    model.add(Dense(l2, activation='relu'))
    model.add(Dense(1, activation='sigmoid')) 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(train_set, train_labels, epochs=150, batch_size=10, verbose=0)
    test_prediction = (model.predict(test_set) > 0.5).astype("int32")
    acc = accuracy_score(test_labels, test_prediction)
    precision = precision_score(test_labels, test_prediction)
    recall = recall_score(test_labels, test_prediction)
    f1 = f1_score(test_labels, test_prediction)
    print("With Accuracy Metric:")
    print("Accuracy : {}".format(round(acc*100,2)))
    print("Precision : {}".format(precision))
    print("Recall : {}".format(recall))
    print("F1 Score : {}".format(f1))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.metrics.Precision()])
    model.fit(train_set, train_labels, epochs=150, batch_size=10, verbose=0)
    test_prediction = (model.predict(test_set) > 0.5).astype("int32")
    acc = accuracy_score(test_labels, test_prediction)
    precision = precision_score(test_labels, test_prediction)
    recall = recall_score(test_labels, test_prediction)
    f1 = f1_score(test_labels, test_prediction)
    print("With Precision Metric:")
    print("Accuracy : {}".format(round(acc*100,2)))
    print("Precision : {}".format(precision))
    print("Recall : {}".format(recall))
    print("F1 Score : {}".format(f1))
    return None

# %%
F1(12,8)
# Out:
# Dimension of Layer 2: 12
# Dimension of Layer 3: 8
# With Accuracy Metric:
# Accuracy : 97.27
# Precision : 0.7464788732394366
# Recall : 0.9695121951219512
# F1 Score : 0.8435013262599469
# With Precision Metric:
# Accuracy : 97.73
# Precision : 0.8010471204188482
# Recall : 0.9329268292682927
# F1 Score : 0.8619718309859156

# %%
F1(6,6)
# Out:
# Dimension of Layer 2: 6
# Dimension of Layer 3: 6
# With Accuracy Metric:
# Accuracy : 96.94
# Precision : 0.7289719626168224
# Recall : 0.9512195121951219
# F1 Score : 0.8253968253968254
# With Precision Metric:
# Accuracy : 96.81
# Precision : 0.7411167512690355
# Recall : 0.8902439024390244
# F1 Score : 0.8088642659279778

# %%
F1(12,12)
# Out:
# Dimension of Layer 2: 12
# Dimension of Layer 3: 12
# With Accuracy Metric:
# Accuracy : 96.81
# Precision : 0.7540106951871658
# Recall : 0.8597560975609756
# F1 Score : 0.8034188034188035
# With Precision Metric:
# Accuracy : 97.69
# Precision : 0.7688679245283019
# Recall : 0.9939024390243902
# F1 Score : 0.8670212765957446

# %%
F1(12,6)
# Out:
# Dimension of Layer 2: 12
# Dimension of Layer 3: 6
# With Accuracy Metric:
# Accuracy : 97.08
# Precision : 0.7224669603524229
# Recall : 1.0
# F1 Score : 0.8388746803069054
# With Precision Metric:
# Accuracy : 97.18
# Precision : 0.7536945812807881
# Recall : 0.9329268292682927
# F1 Score : 0.8337874659400545

# %%
#experiment by adding more layers
print("Dimension of Layer 2: {}".format(12))
print("Dimension of Layer 3: {}".format(10))
print("Dimension of Layer 4: {}".format(8))
model = Sequential()
model.add(Dense(12, input_dim=6, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid')) 
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(train_set, train_labels, epochs=150, batch_size=10, verbose=0)
test_prediction = (model.predict(test_set) > 0.5).astype("int32")
acc = accuracy_score(test_labels, test_prediction)
precision = precision_score(test_labels, test_prediction)
recall = recall_score(test_labels, test_prediction)
f1 = f1_score(test_labels, test_prediction)
print("With Accuracy Metric:")
print("Accuracy : {}".format(round(acc*100,2)))
print("Precision : {}".format(precision))
print("Recall : {}".format(recall))
print("F1 Score : {}".format(f1))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.metrics.Precision()])
model.fit(train_set, train_labels, epochs=150, batch_size=10, verbose=0)
test_prediction = (model.predict(test_set) > 0.5).astype("int32")
acc = accuracy_score(test_labels, test_prediction)
precision = precision_score(test_labels, test_prediction)
recall = recall_score(test_labels, test_prediction)
f1 = f1_score(test_labels, test_prediction)
print("With Precision Metric:")
print("Accuracy : {}".format(round(acc*100,2)))
print("Precision : {}".format(precision))
print("Recall : {}".format(recall))
print("F1 Score : {}".format(f1))
# Out:
# Dimension of Layer 2: 12
# Dimension of Layer 3: 10
# Dimension of Layer 4: 8
# With Accuracy Metric:
# Accuracy : 97.18
# Precision : 0.7536945812807881
# Recall : 0.9329268292682927
# F1 Score : 0.8337874659400545
# With Precision Metric:
# Accuracy : 96.94
# Precision : 0.7227272727272728
# Recall : 0.9695121951219512
# F1 Score : 0.8281249999999999

# %%
#experimenting by increasing epochs
print("Epochs : {}".format(500))
print("Dimension of Layer 2: {}".format(12))
print("Dimension of Layer 3: {}".format(8))
model = Sequential()
model.add(Dense(12, input_dim=6, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid')) 
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(train_set, train_labels, epochs=500, batch_size=10, verbose=0)
test_prediction = (model.predict(test_set) > 0.5).astype("int32")
acc = accuracy_score(test_labels, test_prediction)
precision = precision_score(test_labels, test_prediction)
recall = recall_score(test_labels, test_prediction)
f1 = f1_score(test_labels, test_prediction)
print("With Accuracy Metric:")
print("Accuracy : {}".format(round(acc*100,2)))
print("Precision : {}".format(precision))
print("Recall : {}".format(recall))
print("F1 Score : {}".format(f1))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.metrics.Precision()])
model.fit(train_set, train_labels, epochs=500, batch_size=10, verbose=0)
test_prediction = (model.predict(test_set) > 0.5).astype("int32")
acc = accuracy_score(test_labels, test_prediction)
precision = precision_score(test_labels, test_prediction)
recall = recall_score(test_labels, test_prediction)
f1 = f1_score(test_labels, test_prediction)
print("With Precision Metric:")
print("Accuracy : {}".format(round(acc*100,2)))
print("Precision : {}".format(precision))
print("Recall : {}".format(recall))
print("F1 Score : {}".format(f1))
# Out:
# Epochs : 500
# Dimension of Layer 2: 12
# Dimension of Layer 3: 8
# With Accuracy Metric:
# Accuracy : 97.73
# Precision : 0.7725118483412322
# Recall : 0.9939024390243902
# F1 Score : 0.8693333333333333
# With Precision Metric:
# Accuracy : 97.41
# Precision : 0.75
# Recall : 0.9878048780487805
# F1 Score : 0.8526315789473684

# %%
#Bigger Batch size
print("Epochs : {}".format(150))
print("Batch Size : {}".format(50))
print("Dimension of Layer 2: {}".format(12))
print("Dimension of Layer 3: {}".format(8))
model = Sequential()
model.add(Dense(12, input_dim=6, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid')) 
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(train_set, train_labels, epochs=150, batch_size=50, verbose=0)
test_prediction = (model.predict(test_set) > 0.5).astype("int32")
acc = accuracy_score(test_labels, test_prediction)
precision = precision_score(test_labels, test_prediction)
recall = recall_score(test_labels, test_prediction)
f1 = f1_score(test_labels, test_prediction)
print("With Accuracy Metric:")
print("Accuracy : {}".format(round(acc*100,2)))
print("Precision : {}".format(precision))
print("Recall : {}".format(recall))
print("F1 Score : {}".format(f1))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.metrics.Precision()])
model.fit(train_set, train_labels, epochs=150, batch_size=50, verbose=0)
test_prediction = (model.predict(test_set) > 0.5).astype("int32")
acc = accuracy_score(test_labels, test_prediction)
precision = precision_score(test_labels, test_prediction)
recall = recall_score(test_labels, test_prediction)
f1 = f1_score(test_labels, test_prediction)
print("With Precision Metric:")
print("Accuracy : {}".format(round(acc*100,2)))
print("Precision : {}".format(precision))
print("Recall : {}".format(recall))
print("F1 Score : {}".format(f1))
# Out:
# Epochs : 150
# Batch Size : 50
# Dimension of Layer 2: 12
# Dimension of Layer 3: 8
# With Accuracy Metric:
# Accuracy : 94.77
# Precision : 0.7802197802197802
# Recall : 0.4329268292682927
# F1 Score : 0.5568627450980392
# With Precision Metric:
# Accuracy : 94.63
# Precision : 0.7790697674418605
# Recall : 0.40853658536585363
# F1 Score : 0.536

# %%
#Smaller Batch size
print("Epochs : {}".format(150))
print("Batch Size : {}".format(5))
print("Dimension of Layer 2: {}".format(12))
print("Dimension of Layer 3: {}".format(8))
model = Sequential()
model.add(Dense(12, input_dim=6, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid')) 
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(train_set, train_labels, epochs=150, batch_size=5, verbose=0)
test_prediction = (model.predict(test_set) > 0.5).astype("int32")
acc = accuracy_score(test_labels, test_prediction)
precision = precision_score(test_labels, test_prediction)
recall = recall_score(test_labels, test_prediction)
f1 = f1_score(test_labels, test_prediction)
print("With Accuracy Metric:")
print("Accuracy : {}".format(round(acc*100,2)))
print("Precision : {}".format(precision))
print("Recall : {}".format(recall))
print("F1 Score : {}".format(f1))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.metrics.Precision()])
model.fit(train_set, train_labels, epochs=150, batch_size=5, verbose=0)
test_prediction = (model.predict(test_set) > 0.5).astype("int32")
acc = accuracy_score(test_labels, test_prediction)
precision = precision_score(test_labels, test_prediction)
recall = recall_score(test_labels, test_prediction)
f1 = f1_score(test_labels, test_prediction)
print("With Precision Metric:")
print("Accuracy : {}".format(round(acc*100,2)))
print("Precision : {}".format(precision))
print("Recall : {}".format(recall))
print("F1 Score : {}".format(f1))
# Out:
# Epochs : 150
# Batch Size : 5
# Dimension of Layer 2: 12
# Dimension of Layer 3: 8
# With Accuracy Metric:
# Accuracy : 97.22
# Precision : 0.7321428571428571
# Recall : 1.0
# F1 Score : 0.8453608247422679
# With Precision Metric:
# Accuracy : 97.22
# Precision : 0.7342342342342343
# Recall : 0.9939024390243902
# F1 Score : 0.844559585492228

# %% [markdown]
# #### Plotting histograms based on prediction values
#
# Now, you will plot 2 historgrams of prediction values (0 to 1, or 0% to 100%) on the training data, output by your nn model - one histogram for positive samples and another for negative samples. Plot both the histograms in the same figure.
#
# Here's one such plot I made with my nn model:
# <img src="files/index.jpeg">
#
# The blue histogram is for negative samples and the red one is for positive samples (add a legend to the plots, unlike me).
#
# Use log-scale on the y-axis (number of occurances in the given predicted value range), like I have done.
#
# Now, what can you infer from the histograms you got? How should an ideal pair of histograms look like?
